# %% [markdown]
# # Preparation (dùng cái này)

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from tensorflow import keras
import tensorflow as tf
import pandas as pd
import math

tf.random.set_seed(42)  # Set a seed value for TensorFlow
np.random.seed(42)  # Set a seed value for NumPy
random.seed(42)  # Set a seed value for Python's random module

import os
os.environ['PYTHONHASHSEED'] = '0'
os.environ['TF_DETERMINISTIC_OPS'] = '1'
tf.config.list_physical_devices('GPU')
from google.colab import drive

# %%
#it will open a webpage for verifying your google account. if it is successful, the Google colab can link the Google drive
drive.mount('/content/drive')
 # Iterate through the files in the fogsmog folder
    for file in os.listdir(fogsmog_weather):
        # Check if the file is a jpeg or jpg file
        if file.endswith('.jpeg') or file.endswith('.jpg'):
            # Load the image data from the file using TensorFlow
            img = tf.io.read_file(os.path.join(fogsmog_weather, file))
            img = tf.image.decode_jpeg(img, channels=3)
            img = tf.image.resize(img, (100, 100))
            # Assign a label to the file
            label = 'Fogsmog Weather'
            # Add the image data and label to the data list
            data.append((img, label))
    # Iterate through the files in the rain folder
    for file in os.listdir(rain_weather):
      # Check if the file is a jpeg or jpg file
      if file.endswith('.jpeg') or file.endswith('.jpg'):
        # Load the image data from the file using TensorFlow
        img = tf.io.read_file(os.path.join(rain_weather, file))
        img = tf.image.decode_jpeg(img,channels=3)
        img = tf.image.resize(img, (100, 100))
        # Assign a label to the file
        label = 'Rain Weather'
        # Add the image data and label to the data list
        data.append((img, label))

    # Iterate through the files in the rime folder
    for file in os.listdir(rime_weather):
      # Check if the file is a jpeg or jpg file
      if file.endswith('.jpeg') or file.endswith('.jpg'):
        # Load the image data from the file using TensorFlow
        img = tf.io.read_file(os.path.join(rime_weather, file))
        img = tf.image.decode_jpeg(img,channels=3)
        img = tf.image.resize(img, (100, 100))
        # Assign a label to the file
        label = 'Rime Weather'
        # Add the image data and label to the data list
        data.append((img, label))

    # Iterate through the files in the sandstorm folder
    for file in os.listdir(sandstorm_weather):
      # Check if the file is a jpeg or jpg file
      if file.endswith('.jpeg') or file.endswith('.jpg'):
        # Load the image data from the file using TensorFlow
        img = tf.io.read_file(os.path.join(sandstorm_weather, file))
        img = tf.image.decode_jpeg(img,channels=3)
        img = tf.image.resize(img, (100, 100))
        # Assign a label to the file
        label = 'Sandstorm Weather'
        # Add the image data and label to the data list
        data.append((img, label))

    # Iterate through the files in the snow folder
    for file in os.listdir(snow_weather):
      # Check if the file is a jpeg or jpg file
      if file.endswith('.jpeg') or file.endswith('.jpg'):
        # Load the image data from the file using TensorFlow
        img = tf.io.read_file(os.path.join(snow_weather, file))
        img = tf.image.decode_jpeg(img,channels=3)
        img = tf.image.resize(img, (100, 100))
        # Assign a label to the file
        label = 'Snow Weather'
        # Add the image data and label to the data list
        data.append((img, label))
# Out:
# Mounted at /content/drive
# fogsmog  rain  rime  sandstorm	snow

# %%
# Set the paths to the folders containing the image files
fogsmog_weather = '/content/drive/MyDrive/Colab Notebooks/dataset/fogsmog'
rain_weather = '/content/drive/MyDrive/Colab Notebooks/dataset/rain'
rime_weather = '/content/drive/MyDrive/Colab Notebooks/dataset/rime'
sandstorm_weather = '/content/drive/MyDrive/Colab Notebooks/dataset/sandstorm'
snow_weather = '/content/drive/MyDrive/Colab Notebooks/dataset/snow'

# %%
def load_images():
    # Create a list to store the image data and labels
    data = []

    # Iterate through the files in the fogsmog folder
    for file in os.listdir(fogsmog_weather):
        # Check if the file is a jpeg or jpg file
        if file.endswith('.jpeg') or file.endswith('.jpg'):
            # Load the image data from the file using TensorFlow
            img = tf.io.read_file(os.path.join(fogsmog_weather, file))
            img = tf.image.decode_jpeg(img, channels=3)
            img = tf.image.resize(img, (100, 100))
            # Assign a label to the file
            label = 'Fogsmog Weather'
            # Add the image data and label to the data list
            data.append((img, label))
    # Iterate through the files in the rain folder
    for file in os.listdir(rain_weather):
      # Check if the file is a jpeg or jpg file
      if file.endswith('.jpeg') or file.endswith('.jpg'):
        # Load the image data from the file using TensorFlow
        img = tf.io.read_file(os.path.join(rain_weather, file))
        img = tf.image.decode_jpeg(img,channels=3)
        img = tf.image.resize(img, (100, 100))
        # Assign a label to the file
        label = 'Rain Weather'
        # Add the image data and label to the data list
        data.append((img, label))

    # Iterate through the files in the rime folder
    for file in os.listdir(rime_weather):
      # Check if the file is a jpeg or jpg file
      if file.endswith('.jpeg') or file.endswith('.jpg'):
        # Load the image data from the file using TensorFlow
        img = tf.io.read_file(os.path.join(rime_weather, file))
        img = tf.image.decode_jpeg(img,channels=3)
        img = tf.image.resize(img, (100, 100))
        # Assign a label to the file
        label = 'Rime Weather'
        # Add the image data and label to the data list
        data.append((img, label))

    # Iterate through the files in the sandstorm folder
    for file in os.listdir(sandstorm_weather):
      # Check if the file is a jpeg or jpg file
      if file.endswith('.jpeg') or file.endswith('.jpg'):
        # Load the image data from the file using TensorFlow
        img = tf.io.read_file(os.path.join(sandstorm_weather, file))
        img = tf.image.decode_jpeg(img,channels=3)
        img = tf.image.resize(img, (100, 100))
        # Assign a label to the file
        label = 'Sandstorm Weather'
        # Add the image data and label to the data list
        data.append((img, label))

    # Iterate through the files in the snow folder
    for file in os.listdir(snow_weather):
      # Check if the file is a jpeg or jpg file
      if file.endswith('.jpeg') or file.endswith('.jpg'):
        # Load the image data from the file using TensorFlow
        img = tf.io.read_file(os.path.join(snow_weather, file))
        img = tf.image.decode_jpeg(img,channels=3)
        img = tf.image.resize(img, (100, 100))
        # Assign a label to the file
        label = 'Snow Weather'
        # Add the image data and label to the data list
        data.append((img, label))

    return data
data = load_images()

# %%
def prepare_data(data):
    # Shuffle the data and split into train/test sets
    random.shuffle(data)
    train_data, test_data = data[:int(len(data) * 0.7)], data[int(len(data) * 0.7):]

    # Extract the image data and labels from the training data
    X_train, Y_train = zip(*train_data)

    # Extract the image data and labels from the testing data
    X_test, Y_test = zip(*test_data)

    # Convert the image data and labels into NumPy arrays
    X_train = np.array(X_train)
    Y_train = np.array(Y_train)
    X_test = np.array(X_test)
    Y_test = np.array(Y_test)

    # change integers to 32-bit floating point numbers
    X_train = X_train.astype('float32')
    X_test = X_test.astype('float32')

    # normalize each value for each pixel for the entire vector for each input
    X_train /= 255
    X_test /= 255

    # Create a NumPy array with category strings
    categories = np.array(['Fogsmog Weather', 'Rain Weather', 'Rime Weather', 'Sandstorm Weather', 'Snow Weather'])

    # Create a mapping from category strings to integers
    category_map = {'Fogsmog Weather': 0, 'Rain Weather': 1, 'Rime Weather': 2, 'Sandstorm Weather': 3, 'Snow Weather': 4}

    # Encode the categories
    Y_train = np.array([category_map[category] for category in Y_train])
    Y_test = np.array([category_map[category] for category in Y_test])

    return X_train, Y_train, X_test, Y_test, categories

# %%
X_train, Y_train, X_test, Y_test, categories = prepare_data(data)

# %%
def display_images(X_train, Y_train, labels):
    plt.rcParams['figure.figsize'] = (9, 9)

    for i in range(25):
        plt.subplot(5, 5, i+1)
        plt.imshow(X_train[i], interpolation='none')
        plt.title("{}".format(labels[int(Y_train[i])]))
        plt.tight_layout()

# %%
display_images(X_train, Y_train, categories)
# Out:
# <ipython-input-7-2247be3f3704>:5: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(5, 5, i+1)

# %% [markdown]
# # Train Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, Flatten
from tensorflow.keras.layers import MaxPooling2D, Activation, BatchNormalization
from tensorflow.keras.callbacks import TensorBoard, Callback, EarlyStopping
from tensorflow.keras.optimizers import SGD, RMSprop, Adam, Nadam
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras import regularizers
from tensorflow.keras.utils import to_categorical
from keras.optimizers import Adam
from keras.optimizers import AdamW
from sklearn.metrics import cohen_kappa_score
from keras.regularizers import l2

# One-hot encode the labels
Y_train = to_categorical(Y_train, num_classes=5)
Y_test = to_categorical(Y_test, num_classes=5)

# %%
X_train1 = X_train2 = X_train3 = X_train4 = X_train5 = X_train6 = X_train
X_test1 = X_test2 = X_test3 = X_test4 = X_test5 = X_test6 = X_test
Y_train1 = Y_train2 = Y_train3 = Y_train4 = Y_train5 = Y_train6 = Y_train
Y_test1 = Y_test2 = Y_test3 = Y_test4 = Y_test5 = Y_test6 = Y_test

# %%
num_classes = 5
# Keras callbacks (when Tensorboard installed)
keras_callbacks = [EarlyStopping(monitor='val_loss', patience=20, verbose=0)]

# %% [markdown]
# ## Model 1

# %%
#CHAY LAN DAU
#CNN model with two Convolution layers, one Pooling layer with max pooling,
#which are stacked on top of a traditional ANN model
def model_1():
    model = Sequential()
    model.add(Conv2D(32, kernel_size=(3, 3),
                     activation='relu',
                     input_shape=(100, 100, 3)))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes, activation='softmax'))
    model.compile(loss=categorical_crossentropy,
              optimizer=Adam(learning_rate=0.0001,weight_decay=1e-6),
              metrics='accuracy')
    return model

# %%
model1 = model_1()
model1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_2 (Conv2D)           (None, 98, 98, 32)        896
#
#  max_pooling2d_2 (MaxPoolin  (None, 49, 49, 32)        0
#  g2D)
#
#  dropout_3 (Dropout)         (None, 49, 49, 32)        0
#
#  flatten_1 (Flatten)         (None, 76832)             0
#
#  dense_2 (Dense)             (None, 128)               9834624
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 5)                 645
#
# ...
# Total params: 9836165 (37.52 MB)
# Trainable params: 9836165 (37.52 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model1.fit(X_train1, Y_train1,
      batch_size=32,
      epochs=100,
      shuffle=True,
      verbose=2,
      validation_data=(X_test1, Y_test1),
      callbacks=keras_callbacks)
# Out:
# Epoch 1/100
# 60/60 - 2s - loss: 1.3995 - accuracy: 0.4235 - val_loss: 1.1334 - val_accuracy: 0.6051 - 2s/epoch - 38ms/step
# Epoch 2/100
# 60/60 - 1s - loss: 1.1386 - accuracy: 0.5487 - val_loss: 0.9938 - val_accuracy: 0.6638 - 923ms/epoch - 15ms/step
# Epoch 3/100
# 60/60 - 1s - loss: 1.0480 - accuracy: 0.6022 - val_loss: 0.8838 - val_accuracy: 0.6907 - 940ms/epoch - 16ms/step
# Epoch 4/100
# 60/60 - 1s - loss: 0.9828 - accuracy: 0.6179 - val_loss: 0.8258 - val_accuracy: 0.7042 - 933ms/epoch - 16ms/step
# Epoch 5/100
# 60/60 - 1s - loss: 0.9374 - accuracy: 0.6321 - val_loss: 0.8129 - val_accuracy: 0.7115 - 825ms/epoch - 14ms/step
# Epoch 6/100
# 60/60 - 1s - loss: 0.8803 - accuracy: 0.6682 - val_loss: 0.7583 - val_accuracy: 0.7274 - 833ms/epoch - 14ms/step
# Epoch 7/100
# 60/60 - 1s - loss: 0.8194 - accuracy: 0.6850 - val_loss: 0.7365 - val_accuracy: 0.7213 - 788ms/epoch - 13ms/step
# Epoch 8/100
# ...

# %%
# Make predictions on the training set
Y_train_pred1 = model1.predict(X_train1)
Y_train_pred_classes1 = np.argmax(Y_train_pred1, axis=1)
# Make predictions on the testing set
Y_test_pred1 = model1.predict(X_test1)
Y_test_pred_classes1 = np.argmax(Y_test_pred1, axis=1)
# Convert Y_train from one-hot encoded format to multiclass format
Y_train_classes1 = np.argmax(Y_train1, axis=1)
# Convert Y_test from one-hot encoded format to multiclass format
Y_test_classes1 = np.argmax(Y_test1, axis=1)
# Evaluate on training data
train_score1 = model1.evaluate(X_train1, Y_train1, verbose=0)
train_kappa1 = cohen_kappa_score(Y_train_classes1, Y_train_pred_classes1)
print('Train loss:', round(train_score1[0], 4))
print('Train accuracy:', round(train_score1[1], 4))
print("Train Cohen's Kappa:", round(train_kappa1, 3), '\n')

# Evaluate on test data
test_score1 = model1.evaluate(X_test1, Y_test1, verbose=0)
test_kappa1 = cohen_kappa_score(Y_test_classes1, Y_test_pred_classes1)
print('Test loss:', round(test_score1[0], 4))
print('Test accuracy:', round(test_score1[1], 4))
print("Test Cohen's Kappa:", round(test_kappa1, 3))
# Out:
# ...
# 26/26 [==============================] - 0s 4ms/step
# Train loss: 0.0838
# Train accuracy: 0.9838
# Train Cohen's Kappa: 0.98
#
# Test loss: 0.5475
# Test accuracy: 0.791
# Test Cohen's Kappa: 0.738

# %% [markdown]
# ## Model 2

# %%
# Clear the session and set the seed after model_1
tf.keras.backend.clear_session()

# Define and train model_2
import tensorflow as tf
tf.keras.backend.clear_session()
tf.random.set_seed(42)

# %%
def model_2():
    model = Sequential()
    model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', input_shape=(100, 100, 3)))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.5))  # Increased dropout
    model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.5))  # Increased dropout
    model.add(Flatten())
    model.add(Dense(512, activation='relu', kernel_regularizer=l2(0.01)))  # Added L2 regularization
    model.add(Dropout(0.6))  # Increased dropout
    model.add(Dense(num_classes, activation='softmax'))
    model.compile(loss=categorical_crossentropy,
                  optimizer=Adam(learning_rate=0.0001),
                  metrics='accuracy')
    return model

# %%
model2 = model_2()

# %%
model2.fit(X_train2, Y_train2,
      batch_size=32,
      epochs=500,
      shuffle=True,
      verbose=2,
      validation_data=(X_test2, Y_test2),
      callbacks=keras_callbacks)
# Out:
# Epoch 1/500
# 60/60 - 5s - loss: 9.8122 - accuracy: 0.3700 - val_loss: 7.9089 - val_accuracy: 0.4144 - 5s/epoch - 77ms/step
# Epoch 2/500
# 60/60 - 2s - loss: 6.4602 - accuracy: 0.5498 - val_loss: 5.6515 - val_accuracy: 0.5391 - 2s/epoch - 39ms/step
# Epoch 3/500
# 60/60 - 2s - loss: 4.7583 - accuracy: 0.5886 - val_loss: 4.3434 - val_accuracy: 0.6259 - 2s/epoch - 40ms/step
# Epoch 4/500
# 60/60 - 2s - loss: 3.6746 - accuracy: 0.6452 - val_loss: 3.5123 - val_accuracy: 0.6516 - 2s/epoch - 39ms/step
# Epoch 5/500
# 60/60 - 2s - loss: 2.9967 - accuracy: 0.6714 - val_loss: 2.9332 - val_accuracy: 0.6430 - 2s/epoch - 40ms/step
# Epoch 6/500
# 60/60 - 2s - loss: 2.4809 - accuracy: 0.6944 - val_loss: 2.4824 - val_accuracy: 0.6944 - 2s/epoch - 37ms/step
# Epoch 7/500
# 60/60 - 2s - loss: 2.1194 - accuracy: 0.7206 - val_loss: 2.1543 - val_accuracy: 0.6993 - 2s/epoch - 37ms/step
# Epoch 8/500
# ...

# %%
# Make predictions on the training set
Y_train_pred2 = model2.predict(X_train2)
Y_train_pred_classes2 = np.argmax(Y_train_pred2, axis=1)
# Make predictions on the testing set
Y_test_pred2 = model2.predict(X_test2)
Y_test_pred_classes2 = np.argmax(Y_test_pred2, axis=1)
# Convert Y_train from one-hot encoded format to multiclass format
Y_train_classes2 = np.argmax(Y_train2, axis=1)
# Convert Y_test from one-hot encoded format to multiclass format
Y_test_classes2 = np.argmax(Y_test2, axis=1)
# Evaluate on training data
train_score2 = model2.evaluate(X_train2, Y_train2, verbose=0)
train_kappa2 = cohen_kappa_score(Y_train_classes2, Y_train_pred_classes2)
print('Train loss:', round(train_score2[0], 4))
print('Train accuracy:', round(train_score2[1], 4))
print("Train Cohen's Kappa:", round(train_kappa2, 3), '\n')

# Evaluate on test data
test_score2 = model2.evaluate(X_test2, Y_test2, verbose=0)
test_kappa2 = cohen_kappa_score(Y_test_classes2, Y_test_pred_classes2)
print('Test loss:', round(test_score2[0], 4))
print('Test accuracy:', round(test_score2[1], 4))
print("Test Cohen's Kappa:", round(test_kappa2, 3))
# Out:
# ...
# 26/26 [==============================] - 0s 6ms/step
# Train loss: 0.4946
# Train accuracy: 0.9481
# Train Cohen's Kappa: 0.935
#
# Test loss: 0.7761
# Test accuracy: 0.8178
# Test Cohen's Kappa: 0.772

# %% [markdown]
# ## Model 3

# %%
# Clear the session and set the seed after model_1
tf.keras.backend.clear_session()

# Define and train model_2
import tensorflow as tf
tf.keras.backend.clear_session()
tf.random.set_seed(42)

# %%
#CHAY LAN DAU
#NGON NHAT CHO LOAI CHAY LAN DAU
def model_3():
    model = Sequential()
    model.add(Conv2D(32, kernel_size=(3, 3),
                     activation='relu',
                     input_shape=(100, 100, 3)))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.3))  # Increased dropout
    model.add(Flatten())
    model.add(Dense(128, activation='relu', kernel_regularizer=l2(0.01)))  # Added L2 regularization
    model.add(Dropout(0.6))  # Increased dropout
    model.add(Dense(num_classes, activation='softmax'))
    model.compile(loss=categorical_crossentropy,
                  optimizer=AdamW(learning_rate=0.0001,weight_decay=1e-6),
                  metrics='accuracy')
    return model

# %%
model3 = model_3()

# %%
model3.fit(X_train3, Y_train3,
      batch_size=32,
      epochs=500,
      verbose=2,
      validation_data=(X_test3, Y_test3),
      callbacks=keras_callbacks)
# Out:
# Epoch 1/500
# 60/60 - 3s - loss: 3.0978 - accuracy: 0.3983 - val_loss: 2.2249 - val_accuracy: 0.6271 - 3s/epoch - 45ms/step
# Epoch 2/500
# 60/60 - 1s - loss: 2.0475 - accuracy: 0.5393 - val_loss: 1.7168 - val_accuracy: 0.6993 - 979ms/epoch - 16ms/step
# Epoch 3/500
# 60/60 - 1s - loss: 1.7373 - accuracy: 0.5608 - val_loss: 1.5120 - val_accuracy: 0.6993 - 974ms/epoch - 16ms/step
# Epoch 4/500
# 60/60 - 1s - loss: 1.5539 - accuracy: 0.6111 - val_loss: 1.3686 - val_accuracy: 0.7188 - 977ms/epoch - 16ms/step
# Epoch 5/500
# 60/60 - 1s - loss: 1.4506 - accuracy: 0.6221 - val_loss: 1.2983 - val_accuracy: 0.7323 - 879ms/epoch - 15ms/step
# Epoch 6/500
# 60/60 - 1s - loss: 1.3549 - accuracy: 0.6305 - val_loss: 1.2296 - val_accuracy: 0.7090 - 888ms/epoch - 15ms/step
# Epoch 7/500
# 60/60 - 1s - loss: 1.2784 - accuracy: 0.6462 - val_loss: 1.1689 - val_accuracy: 0.7249 - 880ms/epoch - 15ms/step
# Epoch 8/500
# ...

# %%
# Make predictions on the training set
Y_train_pred3 = model3.predict(X_train3)
Y_train_pred_classes3 = np.argmax(Y_train_pred3, axis=1)
# Make predictions on the testing set
Y_test_pred3 = model3.predict(X_test3)
Y_test_pred_classes3 = np.argmax(Y_test_pred3, axis=1)
# Convert Y_train from one-hot encoded format to multiclass format
Y_train_classes3 = np.argmax(Y_train3, axis=1)
# Convert Y_test from one-hot encoded format to multiclass format
Y_test_classes3 = np.argmax(Y_test3, axis=1)
# Evaluate on training data
train_score3 = model3.evaluate(X_train3, Y_train3, verbose=0)
train_kappa3 = cohen_kappa_score(Y_train_classes3, Y_train_pred_classes3)
print('Train loss:', round(train_score3[0], 4))
print('Train accuracy:', round(train_score3[1], 4))
print("Train Cohen's Kappa:", round(train_kappa3, 3), '\n')

# Evaluate on test data
test_score3 = model3.evaluate(X_test3, Y_test3, verbose=0)
test_kappa3 = cohen_kappa_score(Y_test_classes3, Y_test_pred_classes3)
print('Test loss:', round(test_score3[0], 4))
print('Test accuracy:', round(test_score3[1], 4))
print("Test Cohen's Kappa:", round(test_kappa3, 3))
# Out:
# ...
# 26/26 [==============================] - 0s 4ms/step
# Train loss: 0.3379
# Train accuracy: 0.968
# Train Cohen's Kappa: 0.96
#
# Test loss: 0.6868
# Test accuracy: 0.802
# Test Cohen's Kappa: 0.752

# %% [markdown]
# ## Model 4

# %%
# Clear the session and set the seed after model_1
tf.keras.backend.clear_session()

# Define and train model_2
import tensorflow as tf
tf.keras.backend.clear_session()
tf.random.set_seed(42)

# %%
def model_4():
    model = Sequential()
    model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', input_shape=(100, 100, 3)))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.4))  # Increased dropout
    model.add(Conv2D(32, kernel_size=(3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.4))  # Increased dropout
    model.add(Flatten())
    model.add(Dense(128, activation='relu', kernel_regularizer=l2(0.01)))  # Added L2 regularization
    model.add(Dropout(0.6))  # Increased dropout
    model.add(Dense(num_classes, activation='softmax'))
    model.compile(loss=categorical_crossentropy,
                  optimizer=AdamW(learning_rate=0.0001, weight_decay=1e-6),
                  metrics='accuracy')
    return model

# %%
model4 = model_4()
model4.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 98, 98, 64)        1792
#
#  max_pooling2d (MaxPooling2  (None, 49, 49, 64)        0
#  D)
#
#  dropout (Dropout)           (None, 49, 49, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 47, 47, 32)        18464
#
#  max_pooling2d_1 (MaxPoolin  (None, 23, 23, 32)        0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 23, 23, 32)        0
#
#  flatten (Flatten)           (None, 16928)             0
#
#  dense (Dense)               (None, 128)               2166912
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 5)                 645
#
# ...
# Total params: 2187813 (8.35 MB)
# Trainable params: 2187813 (8.35 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model4.fit(X_train4, Y_train4,
      batch_size=32,
      epochs=500,
      verbose=2,
      validation_data=(X_test4, Y_test4),
      callbacks=keras_callbacks)
# Out:
# Epoch 1/500
# 60/60 - 3s - loss: 3.8816 - accuracy: 0.2600 - val_loss: 3.5412 - val_accuracy: 0.3936 - 3s/epoch - 55ms/step
# Epoch 2/500
# 60/60 - 1s - loss: 3.2003 - accuracy: 0.3884 - val_loss: 2.9717 - val_accuracy: 0.5538 - 1s/epoch - 20ms/step
# Epoch 3/500
# 60/60 - 1s - loss: 2.7141 - accuracy: 0.4691 - val_loss: 2.5915 - val_accuracy: 0.5868 - 1s/epoch - 20ms/step
# Epoch 4/500
# 60/60 - 1s - loss: 2.3854 - accuracy: 0.5514 - val_loss: 2.3185 - val_accuracy: 0.5966 - 1s/epoch - 24ms/step
# Epoch 5/500
# 60/60 - 1s - loss: 2.1568 - accuracy: 0.5603 - val_loss: 2.0859 - val_accuracy: 0.6394 - 1s/epoch - 24ms/step
# Epoch 6/500
# 60/60 - 1s - loss: 1.9710 - accuracy: 0.5954 - val_loss: 1.9133 - val_accuracy: 0.6736 - 1s/epoch - 21ms/step
# Epoch 7/500
# 60/60 - 1s - loss: 1.7936 - accuracy: 0.6420 - val_loss: 1.7671 - val_accuracy: 0.6773 - 1s/epoch - 20ms/step
# Epoch 8/500
# ...

# %%
# Make predictions on the training set
Y_train_pred4 = model4.predict(X_train4)
Y_train_pred_classes4 = np.argmax(Y_train_pred4, axis=1)
# Make predictions on the testing set
Y_test_pred4 = model4.predict(X_test4)
Y_test_pred_classes4 = np.argmax(Y_test_pred4, axis=1)
# Convert Y_train from one-hot encoded format to multiclass format
Y_train_classes4 = np.argmax(Y_train4, axis=1)
# Convert Y_test from one-hot encoded format to multiclass format
Y_test_classes4 = np.argmax(Y_test4, axis=1)
# Evaluate on training data
train_score4 = model4.evaluate(X_train4, Y_train4, verbose=0)
train_kappa4 = cohen_kappa_score(Y_train_classes4, Y_train_pred_classes4)
print('Train loss:', round(train_score4[0], 4))
print('Train accuracy:', round(train_score4[1], 4))
print("Train Cohen's Kappa:", round(train_kappa4, 3), '\n')

# Evaluate on test data
test_score4 = model4.evaluate(X_test4, Y_test4, verbose=0)
test_kappa4 = cohen_kappa_score(Y_test_classes4, Y_test_pred_classes4)
print('Test loss:', round(test_score4[0], 4))
print('Test accuracy:', round(test_score4[1], 4))
print("Test Cohen's Kappa:", round(test_kappa4, 3))
# Out:
# ...
# 26/26 [==============================] - 0s 5ms/step
# Train loss: 0.3687
# Train accuracy: 0.9397
# Train Cohen's Kappa: 0.925
#
# Test loss: 0.6548
# Test accuracy: 0.7922
# Test Cohen's Kappa: 0.74

# %% [markdown]
# ## Model 5

# %%
# Clear the session and set the seed after model_1
tf.keras.backend.clear_session()

# Define and train model_2
import tensorflow as tf
tf.keras.backend.clear_session()
tf.random.set_seed(42)

# %%
def model_5():
    model = Sequential()
    model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(100, 100, 3)))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.3))  # Increased dropout
    model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.3))  # Increased dropout
    model.add(Flatten())
    model.add(Dense(256, activation='relu', kernel_regularizer=l2(0.01)))  # Added L2 regularization
    model.add(Dropout(0.6))  # Increased dropout
    model.add(Dense(num_classes, activation='softmax'))
    model.compile(loss=categorical_crossentropy,
                  optimizer=Adam(learning_rate=0.0001),
                  metrics='accuracy')
    return model

# %%
model5 = model_5()
model5.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 98, 98, 32)        896
#
#  max_pooling2d (MaxPooling2  (None, 49, 49, 32)        0
#  D)
#
#  dropout (Dropout)           (None, 49, 49, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 47, 47, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 23, 23, 64)        0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 23, 23, 64)        0
#
#  flatten (Flatten)           (None, 33856)             0
#
#  dense (Dense)               (None, 256)               8667392
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 5)                 1285
#
# ...
# Total params: 8688069 (33.14 MB)
# Trainable params: 8688069 (33.14 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model5.fit(X_train5, Y_train5,
      batch_size=32,
      epochs=500,
      verbose=2,
      validation_data=(X_test5, Y_test5),
      callbacks=keras_callbacks)
# Out:
# Epoch 1/500
# 60/60 - 3s - loss: 5.6895 - accuracy: 0.3035 - val_loss: 4.7047 - val_accuracy: 0.4267 - 3s/epoch - 55ms/step
# Epoch 2/500
# 60/60 - 1s - loss: 3.9612 - accuracy: 0.4539 - val_loss: 3.4632 - val_accuracy: 0.6222 - 1s/epoch - 18ms/step
# Epoch 3/500
# 60/60 - 1s - loss: 3.0409 - accuracy: 0.5409 - val_loss: 2.7496 - val_accuracy: 0.6210 - 1s/epoch - 18ms/step
# Epoch 4/500
# 60/60 - 1s - loss: 2.4580 - accuracy: 0.6080 - val_loss: 2.3080 - val_accuracy: 0.6565 - 1s/epoch - 19ms/step
# Epoch 5/500
# 60/60 - 1s - loss: 2.1018 - accuracy: 0.6284 - val_loss: 1.9958 - val_accuracy: 0.6858 - 1s/epoch - 19ms/step
# Epoch 6/500
# 60/60 - 1s - loss: 1.8360 - accuracy: 0.6468 - val_loss: 1.7763 - val_accuracy: 0.6907 - 1s/epoch - 22ms/step
# Epoch 7/500
# 60/60 - 1s - loss: 1.6417 - accuracy: 0.6667 - val_loss: 1.6070 - val_accuracy: 0.6993 - 1s/epoch - 18ms/step
# Epoch 8/500
# ...

# %%
# Make predictions on the training set
Y_train_pred5 = model5.predict(X_train5)
Y_train_pred_classes5 = np.argmax(Y_train_pred5, axis=1)
# Make predictions on the testing set
Y_test_pred5 = model5.predict(X_test5)
Y_test_pred_classes5 = np.argmax(Y_test_pred5, axis=1)
# Convert Y_train from one-hot encoded format to multiclass format
Y_train_classes5 = np.argmax(Y_train5, axis=1)
# Convert Y_test from one-hot encoded format to multiclass format
Y_test_classes5 = np.argmax(Y_test5, axis=1)
# Evaluate on training data
train_score5 = model5.evaluate(X_train5, Y_train5, verbose=0)
train_kappa5 = cohen_kappa_score(Y_train_classes5, Y_train_pred_classes5)
print('Train loss:', round(train_score5[0], 4))
print('Train accuracy:', round(train_score5[1], 4))
print("Train Cohen's Kappa:", round(train_kappa5, 3), '\n')

# Evaluate on test data
test_score5 = model5.evaluate(X_test5, Y_test5, verbose=0)
test_kappa5 = cohen_kappa_score(Y_test_classes5, Y_test_pred_classes5)
print('Test loss:', round(test_score5[0], 4))
print('Test accuracy:', round(test_score5[1], 4))
print("Test Cohen's Kappa:", round(test_kappa5, 3))
# Out:
# ...
# 26/26 [==============================] - 0s 5ms/step
# Train loss: 0.3962
# Train accuracy: 0.9324
# Train Cohen's Kappa: 0.915
#
# Test loss: 0.6797
# Test accuracy: 0.802
# Test Cohen's Kappa: 0.752

# %% [markdown]
# # Model 6

# %%
# Clear the session and set the seed after model_1
tf.keras.backend.clear_session()

# Define and train model_2
import tensorflow as tf
tf.keras.backend.clear_session()
tf.random.set_seed(42)

# %%
def model_6():
    model = Sequential()
    model.add(Conv2D(32, kernel_size=(5, 5), activation='relu', input_shape=(100, 100, 3)))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.4))  # Increased dropout
    model.add(Conv2D(64, kernel_size=(5, 5), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.4))  # Increased dropout
    model.add(Flatten())
    model.add(Dense(256, activation='relu', kernel_regularizer=l2(0.01)))  # Added L2 regularization
    model.add(Dropout(0.6))  # Increased dropout
    model.add(Dense(num_classes, activation='softmax'))
    model.compile(loss=categorical_crossentropy,
                  optimizer=AdamW(learning_rate=0.0001, weight_decay=1e-6),
                  metrics='accuracy')
    return model

# %%
model6 = model_6()
model6.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 96, 96, 32)        2432
#
#  max_pooling2d (MaxPooling2  (None, 48, 48, 32)        0
#  D)
#
#  dropout (Dropout)           (None, 48, 48, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 44, 44, 64)        51264
#
#  max_pooling2d_1 (MaxPoolin  (None, 22, 22, 64)        0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 22, 22, 64)        0
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 256)               7930112
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 5)                 1285
#
# ...
# Total params: 7985093 (30.46 MB)
# Trainable params: 7985093 (30.46 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model6.fit(X_train6, Y_train6,
      batch_size=32,
      epochs=500,
      verbose=2,
      validation_data=(X_test5, Y_test5),
      callbacks=keras_callbacks)
# Out:
# Epoch 1/500
# 60/60 - 4s - loss: 5.7360 - accuracy: 0.3679 - val_loss: 4.8126 - val_accuracy: 0.5929 - 4s/epoch - 62ms/step
# Epoch 2/500
# 60/60 - 1s - loss: 4.0644 - accuracy: 0.5928 - val_loss: 3.6129 - val_accuracy: 0.6907 - 1s/epoch - 20ms/step
# Epoch 3/500
# 60/60 - 1s - loss: 3.2382 - accuracy: 0.6384 - val_loss: 2.9943 - val_accuracy: 0.6895 - 1s/epoch - 20ms/step
# Epoch 4/500
# 60/60 - 1s - loss: 2.6921 - accuracy: 0.6656 - val_loss: 2.5633 - val_accuracy: 0.7017 - 1s/epoch - 20ms/step
# Epoch 5/500
# 60/60 - 1s - loss: 2.3543 - accuracy: 0.6635 - val_loss: 2.2581 - val_accuracy: 0.6944 - 1s/epoch - 20ms/step
# Epoch 6/500
# 60/60 - 1s - loss: 2.0531 - accuracy: 0.7070 - val_loss: 2.0045 - val_accuracy: 0.7200 - 1s/epoch - 21ms/step
# Epoch 7/500
# 60/60 - 1s - loss: 1.8177 - accuracy: 0.7180 - val_loss: 1.7809 - val_accuracy: 0.7164 - 1s/epoch - 22ms/step
# Epoch 8/500
# ...

# %%
# Make predictions on the training set
Y_train_pred6 = model6.predict(X_train6)
Y_train_pred_classes6 = np.argmax(Y_train_pred6, axis=1)
# Make predictions on the testing set
Y_test_pred6 = model6.predict(X_test6)
Y_test_pred_classes6 = np.argmax(Y_test_pred6, axis=1)
# Convert Y_train from one-hot encoded format to multiclass format
Y_train_classes6 = np.argmax(Y_train6, axis=1)
# Convert Y_test from one-hot encoded format to multiclass format
Y_test_classes6 = np.argmax(Y_test6, axis=1)
# Evaluate on training data
train_score6 = model6.evaluate(X_train6, Y_train6, verbose=0)
train_kappa6 = cohen_kappa_score(Y_train_classes6, Y_train_pred_classes6)
print('Train loss:', round(train_score6[0], 4))
print('Train accuracy:', round(train_score6[1], 4))
print("Train Cohen's Kappa:", round(train_kappa6, 3), '\n')

# Evaluate on test data
test_score6 = model6.evaluate(X_test6, Y_test6, verbose=0)
test_kappa6 = cohen_kappa_score(Y_test_classes6, Y_test_pred_classes6)
print('Test loss:', round(test_score6[0], 4))
print('Test accuracy:', round(test_score6[1], 4))
print("Test Cohen's Kappa:", round(test_kappa6, 3))
# Out:
# ...
# 26/26 [==============================] - 0s 6ms/step
# Train loss: 0.4378
# Train accuracy: 0.9371
# Train Cohen's Kappa: 0.921
#
# Test loss: 0.7681
# Test accuracy: 0.7885
# Test Cohen's Kappa: 0.736

# %%
import pandas as pd

# Assuming you have lists of your results like this:
train_loss = [train_score1[0], train_score3[0], train_score2[0], train_score4[0], train_score5[0], train_score6[0]]
test_loss = [test_score1[0], test_score3[0], test_score2[0], test_score4[0], test_score5[0], test_score6[0]]
train_accuracy = [train_score1[1], train_score3[1], train_score3[1], train_score4[1], train_score5[1], train_score6[1]]
test_accuracy = [test_score1[1], test_score3[1], test_score2[1], test_score4[1], test_score5[1], test_score6[1]]
train_kappa = [train_kappa1, train_kappa3, train_kappa2, train_kappa4, train_kappa5, train_kappa6]
test_kappa = [test_kappa1, test_kappa3, test_kappa2, test_kappa4, test_kappa5, test_kappa6]

# Create a DataFrame
df = pd.DataFrame({
    'Model': ['Model 1', 'Model 2', 'Model 3', 'Model 4', 'Model 5', 'Model 6'],
    'Train Loss': train_loss,
    'Test Loss': test_loss,
    'Train Accuracy': train_accuracy,
    'Test Accuracy': test_accuracy,
    'Train Kappa': train_kappa,
    'Test Kappa': test_kappa
})

# Display the DataFrame as a table
df
# Out:
#      Model  Train Loss  Test Loss  Train Accuracy  Test Accuracy  Train Kappa  \
# 0  Model 1    0.124657   0.594300        0.971174       0.773839     0.963958
# 1  Model 2    0.337925   0.686774        0.968029       0.801956     0.960035
# 2  Model 3    0.494576   0.776133        0.968029       0.817848     0.935129
# 3  Model 4    0.368720   0.654808        0.939727       0.792176     0.924641
# 4  Model 5    0.396238   0.679669        0.932390       0.801956     0.915462
# 5  Model 6    0.437815   0.768135        0.937107       0.788509     0.921344
#
#    Test Kappa
# 0    0.717381
# 1    0.751983
# 2    0.772150
# 3    0.740082
# 4    0.752343
# 5    0.735652
